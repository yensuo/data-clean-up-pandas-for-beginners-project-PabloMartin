# %% [markdown]
# # Prácticas básicas con Python
#
# #### Ejercicio 00. Declaración de Variables
#
# Define las siguientes variables con valores que tú elijas:
#
# - Una variable que almacene tu nombre (texto).
# - Una variable que almacene tu edad (número entero).
# - Una variable que indique si te gusta la programación (verdadero o falso).
# - Una variable que almacene tu calificación promedio (número decimal).

# %%
# Declara aquí tus variables.

#Ejemplo
saludo = "Hola mundo" 
nombre = "Pablo"
edad = 27
me_gusta_programar = True 
calificacion_promedio = 7.4

# %% [markdown]
# - Crea una lista con tus cinco números favoritos e imprimelo.

# %%
# Lista de números favoritos
lista = [x for x in range(5)]
lista
# Out:
# [0, 1, 2, 3, 4]

# %% [markdown]
# - Crea un diccionario que guarde la información de un estudiante e imprimelo:
#
#         - Nombre
#         - Edad
#         - Calificación final

# %%
# Diccionario del estudiante
dicc = {"Nombre" : "Pablo" ,
"Edad" : 27 ,
"Calificación final" : 10
}
dicc
# Out:
# {'Nombre': 'Pablo', 'Edad': 27, 'Calificación final': 10}

# %% [markdown]
# #### Ejercicio 01. Análisis de datos básico con estructuras nativas de python.
# Crea una lista con las calificaciones de 5 estudiantes: [8.5, 9.2, 7.8, 8.9, 10].
#
# - Calcula el promedio de las calificaciones.

# %%
# Código
calificaciones =  [8.5, 9.2, 7.8, 8.9, 10] 
suma = 0
for calificacion in calificaciones:
    suma += calificacion

suma / len(calificaciones)
# Out:
# 8.879999999999999

# %% [markdown]
# - Encuentra la calificación más alta y la más baja.

# %%
# Código
maxima = max(calificaciones)
minima = min (calificaciones)

print(f"maxima: {maxima} \nminima : {minima}")
# Out:
# maxima: 10
# minima : 7.8

# %% [markdown]
# # Limpieza de bienes raíces con Pandas para un análisis eficiente
#
# Este es un conjunto de datos (dataset) reales que fue descargado usando técnicas de web scraping. La data contiene registros de **Fotocasa**, el cual es uno de los sitios más populares de bienes raíces en España. Por favor no hagas esto (web scraping) a no ser que sea para propósitos académicos.
#
# El dataset fue descargado hace algunos años por Henry Navarro y en ningún caso se obtuvo beneficio económico de ello.
#
# Contiene miles de datos de casas reales publicadas en la web www.fotocasa.com. Tu objetivo es extraer tanta información como sea posible con el conocimiento que tienes hasta ahora de ciencia de datos.
#
# ¡Comencemos!
#
#
#
#
# - Primero leamos y exploraremos el dataset

# %%
import pandas as pd

# Leer el archivo CSV
df = pd.read_csv('assets/real_estate.csv', sep=';') # Este archivo CSV contiene puntos y comas en lugar de comas como separadores
df # mostramos todo
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
# ...

# %% [markdown]
# - Muestra las primeras filas del archivo CSV

# %%
# Mostrar las primeras filas
df.columns
# Out:
# Index(['Unnamed: 0', 'id_realEstates', 'isNew', 'realEstate_name',
#        'phone_realEstate', 'url_inmueble', 'rooms', 'bathrooms', 'surface',
#        'price', 'date', 'description', 'address', 'country', 'level1',
#        'level2', 'level3', 'level4', 'level5', 'level6', 'level7', 'level8',
#        'upperLevel', 'countryId', 'level1Id', 'level2Id', 'level3Id',
#        'level4Id', 'level5Id', 'level6Id', 'level7Id', 'level8Id', 'accuracy',
#        'latitude', 'longitude', 'zipCode', 'customZone'],
#       dtype='str')

# %% [markdown]
# Perfecto, esto fue una pequeña practica. ¡Ahora empecemos con los verdaderos ejercicios!

# %% [markdown]
# #### Ejercicio 01. ¿Cuál es la casa más cara en todo el dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle del Prado, Nº20 es la más cara y su precio es de 5000000 USD`

# %% [markdown]
# ORDENAR Y GUARDAR DATAFRAME CON SORT VALUES Y RESET INDEX

# %%
#df.sort_values("price" , ascending = False).reset_index()["address"][0]

# %% [markdown]
# EJERCICIO 1

# %%
# TODO
casa_mas_cara_dir = df.nlargest(1, "price")["address"].values[0]

casa_mas_cara_price = df.nlargest(1, "price")["price"].values[0]

f"La casa con dirección en {casa_mas_cara_dir} es la más cara y su precio es de {casa_mas_cara_price} USD"
# Out:
# 'La casa con dirección en El Escorial es la más cara y su precio es de 8500000 USD'

# %% [markdown]
# #### Ejercicio 02. ¿Cuál es la casa más barata del dataset? (★☆☆)
#
# Este ejercicio es similar al ejercicio anterior, solo que ahora buscamos la casa con el precio más bajo. Recuerda imprimir la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle Alcalá, Nº58 es la más barata y su precio es de 12000 USD`

# %%
# TODO
casa_mas_barata_dir = df.nsmallest(1, "price")["address"].values[0]

casa_mas_barata_price = df.nsmallest(1, "price")["price"].values[0]

f"La casa con dirección en {casa_mas_barata_dir} es la más barata y su precio es de {casa_mas_barata_price} USD"
# Out:
# 'La casa con dirección en Parla es la más barata y su precio es de 0 USD'

# %% [markdown]
# #### Ejercicio 03. ¿Cuál es la casa más grande y la más pequeña del dataset? (★☆☆)
#
# Imprime la dirección y el área de las casas seleccionadas. Por ejemplo:
#
# `La casa más grande está ubicada en Calle Gran Vía, Nº38 y su superficie es de 5000 metros`
#
# `La casa más pequeña está ubicada en Calle Mayor, Nº12 y su superficie es de 200 metros`
#
# Este ejercicio es similar al anterior, pero buscamos las casas más grandes y pequeñas en base a su superficie.

# %%
# TODO
casa_mas_grande_dir = df.nlargest(1 , "surface")["address"].values[0]
casa_mas_grande_sur = df.nlargest(1 , "surface")["surface"].values[0]

casa_mas_pequeña_dir = df.nsmallest(1 , "surface")["address"].values[0]
casa_mas_pequeña_sur = df.nsmallest(1 , "surface")["surface"].values[0]

frase_grande = f'La casa más grande está ubicada en {casa_mas_grande_dir} y su superficie es de {casa_mas_grande_sur} metros'

frase_pequeña = f'La casa más pequeña está ubicada en {casa_mas_pequeña_dir} y su superficie es de {casa_mas_pequeña_sur} metros'

print(frase_grande)
print(frase_pequeña)
# Out:
# La casa más grande está ubicada en Sevilla la Nueva y su superficie es de 249000.0 metros
# La casa más pequeña está ubicada en Calle Amparo,  Madrid Capital y su superficie es de 15.0 metros

# %% [markdown]
# #### Ejercicio 04. ¿Cuantas poblaciones contiene el dataset? (★☆☆)
#
# Cuenta el número de poblaciones únicas en la columna 'level5' e imprime el nombre de las poblaciones separadas por coma. Por ejemplo:
#
# `> print(populations)`
#
# `population1, population2, population3, ...`

# %%
# TODO
localidades = df.level5.unique()
n_localidades = len(localidades)

print(f"Número de localidades: {n_localidades}")
print("Lista de localidades:" , ", ".join(localidades))
# Out:
# Número de localidades: 168
# ...

# %% [markdown]
# #### Ejercicio 05. ¿El dataset contiene valores nulos (NAs)? (★☆☆)
#
# Imprima un booleano (`True` o `False`) para verificar si hay valores nulos seguido de las columnas que contiene el NAs.

# %%
# TODO
#df.info() -->Hay nulos en múltiples columnas
nulos_por_columna = df.isnull().sum() #columnas con su cantidad de nulos

hay_nulos = nulos_por_columna > 0 #aplico el filtro para obtener booleanos con valor True en caso de haber nulos
hay_nulos   #imprimo
# Out:
# Unnamed: 0          False
# id_realEstates      False
# isNew               False
# realEstate_name      True
# phone_realEstate     True
# url_inmueble        False
# rooms                True
# bathrooms            True
# surface              True
# price               False
# date                False
# description          True
# address             False
# country             False
# level1              False
# level2              False
# level3              False
# level4               True
# level5              False
# level6               True
# level7               True
# level8               True
# upperLevel          False
# countryId           False
# level1Id            False
# level2Id            False
# level3Id            False
# level4Id            False
# level5Id            False
# level6Id            False
# level7Id            False
# level8Id            False
# accuracy            False
# latitude            False
# longitude           False
# ...

# %% [markdown]
# #### Ejercicio 06. Elimina los valores nulos (NAs) del dataset, si aplica (★★☆)
#
# Despues de eliminar los valores nulos, compara el tamaño del DataFrame antes y después de la eliminación.

# %%
# TODO
tamaño_inicial = df.shape #tamaño inicial
sin_nulos = df.dropna()  #me cargo las filas con nulos
tamaño_final = sin_nulos.shape  #recojo el tamaño tras la eliminacion

print(f"tamaño inicial: {tamaño_inicial}\ntamaño final: {tamaño_final}") #comparacion de tamaños
sin_nulos #imprimo el dataset para verificar que se han eliminado todas las filas
# Out:
# tamaño inicial: (15335, 37)
# tamaño final: (0, 37)
# Empty DataFrame
# Columns: [Unnamed: 0, id_realEstates, isNew, realEstate_name, phone_realEstate, url_inmueble, rooms, bathrooms, surface, price, date, description, address, country, level1, level2, level3, level4, level5, level6, level7, level8, upperLevel, countryId, level1Id, level2Id, level3Id, level4Id, level5Id, level6Id, level7Id, level8Id, accuracy, latitude, longitude, zipCode, customZone]
# Index: []
#
# [0 rows x 37 columns]

# %% [markdown]
# #### Ejercicio 07. ¿Cuál es la media de precios en la población de "Arroyomolinos (Madrid)"? (★★☆)
#
# Imprima el valor obtenido de la columna level5.

# %%
# TODO
arroyomolinos = df[df["level5"] == "Arroyomolinos (Madrid)"] #Filtro por poblacion

media_precios_arroyomolinos = arroyomolinos["price"].mean() #calculo la media de precios con mean

print(f"La media de precios de las casas en Arroyomolinos (Madrid) es {media_precios_arroyomolinos.round(2)}€ aproximadamente")
# Out:
# La media de precios de las casas en Arroyomolinos (Madrid) es 294541.6€ aproximadamente

# %% [markdown]
# #### Ejercicio 08. Trazar el histograma de los precios para la población de "Arroyomolinos (Madrid)" y explica qué observas (★★☆)
#
# Imprime el histograma de los precios y escribe en la celda del Markdown un breve análisis del trazado.

# %%
import matplotlib.pyplot as plt

# Trazar el histograma de precios
precios_arroyomolinos = arroyomolinos.price
precios_arroyomolinos.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# La mayor concentración de precios de casas en Arroyomolinos se produce entre los 200.000€ y los 400.000€, teniendo un pico justo a la mitad de este rango, en los 300.000€.
# Por debajo de este rango apenas hay casas, salvo por una minoría que no llega a los 100.000€.
# A partir de los 400.000€ se reduce drásticamente la cantidad de casas que hay, las cuales tienen precios que casi llegan hasta los 600.000€.
